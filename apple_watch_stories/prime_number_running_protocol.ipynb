# %% [markdown]
# # Apple Watch and the Prime Number Running Protocol

# %% [markdown]
# ## Run Durations That End In Prime Number Minutes

# %% [markdown]
# After putting in more running miles this year than I had in the past few years combined, I needed to find a way to stay motivated and to have some fun. I came up with this running protocol:
#
# 1. No runs shorter than 20 minutes.
#
#
# 2. The duration in minutes should be a prime number.
#
#
# 3. 10 seconds to stop my Apple Watch timer once my run duration hits the desired prime number minutes. Otherwise I have to continue running until I reach the next prime number.

# %% [markdown]
# ### Setup

# %%
import pathlib

# %%
import pandas as pd

# %%
home = pathlib.Path.home()

# %%
study_path = f"{home}/small-data/study/apple-watch-health-tracking/story-data"

# %%
runs = pd.read_csv(f"{study_path}/apple_watch_runs_prime_202009.csv",parse_dates=['date'])

# %% [markdown]
# ### Frequency Distribution of Runs With Prime Number Durations

# %%
grouped_primes = runs.groupby('Prime Number Minutes').count()

# %%
barplot = grouped_primes.plot.bar(y="miles", 
                                  legend=False,
                                  color=['blue', 'orange', 'green', 'red', 'purple'],
                                  title = "Frequency Distribution of September 2020 Runs in Prime Number Minutes",
                                  figsize=(11, 7), rot=0)

# %%
barplot.get_figure().savefig(f"{study_path}/sep2020_prime_frequency")

# %% [markdown]
# ### Prime Number Runs Across September 2020

# %%
runs_plot = runs.plot.line(y=['Prime Number Minutes'],
                           x='date',
                           title='Prime Number Runs, September 2020', 
                           color = 'orange',
                           markevery=1, markersize=14, style='.-',
                           ylim=(20,70),
                           figsize=(17, 11), rot=0)

# %%
runs_plot.get_figure().savefig(f"{study_path}/sep2020_prime_lineplot")

# %% [markdown]
# ### Statistics

# %%
runs.describe().loc[:,["minutes"]]
# Out:
#          minutes
# count  27.000000
# mean   38.898852
# std    12.273601
# min    23.024000
# 25%    30.030000
# 50%    37.058000
# 75%    45.032000
# max    67.033000
